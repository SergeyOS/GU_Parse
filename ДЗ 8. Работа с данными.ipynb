# %% [markdown]
# Тема: Сбор данных о рынке недвижимости в Москве для последующего анализа и предсказания цены

# %% [markdown]
# Спарсим данные с сайта https://domclick.ru/

# %% [markdown]
# 1. Подключение библиотек для прасинша и сохранения данных

# %%
import requests
from bs4 import BeautifulSoup
from pymongo import MongoClient
import time
import pandas as pd

# %% [markdown]
# 1.1. Раздел настроек

# %%
url = 'https://domclick.ru'
params = {'deal_type': 'sale', 'offer_type':'flat', 'category': 'living'}
MAX_PAGE = 100
DEBUG = False

# %% [markdown]
# 1.2. Запросы к серверу

# %%
# Возвращает результат запроса
def html_from_url(url, params, timeout=50):
    msg = ''
    response = requests.Response()
    try:
        headers = {'accept': '*/&*',
                   'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 '
                                 '(KHTML, like Gecko) Chrome/75.0.3770.142 Safari/537.36'}
        response = requests.get(url, params=params, headers=headers, timeout=timeout)
        print(response.url)
    except requests.exceptions.ConnectionError:
        msg = 'Проблемы с интернет соединением'
    except requests.RequestException as e:
        msg = str(e)
    return response.text, response.status_code, msg

# %% [markdown]
# 1.3.Функции обработки страницы

# %%
#обработка цены квартиры
def get_flat_clear_price(tag):
    spam = tag.text.replace(' ', '')
    return  float(spam[:-1]), spam[-1]

#обработка цены метра квратиры
def get_flat_clear_per_square_meter_price(tag):
    spam = float(tag.text.replace(' ₽/м²', '').replace(' ', ''))
    return  spam

#обработка доп. информации о квартире
def get_info_flat(tags):
    rooms = None
    square = None
    floor = None
    house_floor = None
    for i in range(len(tags)):
        if i==0:
            spam = tags[i].text
            if spam == 'студия':
                rooms = 0
            else:
                rooms = int(spam.split('-')[0])
        elif i==1:
            spam = tags[i].text
            square = float(spam.split(' ')[0].replace(',','.'))
        elif i==2:
            spam = tags[i].text
            floor = int(spam.split(' ')[0])
            house_floor = int(spam.split(' ')[-1])
        else:
            break
    return rooms, square, floor, house_floor 

#обработка доп. информации о метро
def get_info_metro(tag):
    metro_line = ''
    metro_station = ''
    if tag.find('span', {'class':'YBcx8'}) is not None:
        metro_line = tag.find('span', {'class':'YBcx8'})['title']
        metro_station = tag.find('span', {'class':'PAT-G'}).text.split(',')[0]
    return  metro_line, metro_station

#обработка 1 страницы
def parse_one_page_sales(url, tag, params, db_collection):
    html_doc, status_code, msg = html_from_url(url+tag, params)    
    next_page = None
    if status_code != 200:
        print(f'Ошибка загрузки страницы {url}: {msg}')
    else:
        soup = BeautifulSoup(html_doc, 'html.parser')    
        items = soup.findAll('a', {'class': '_3_q0k'})
        for item in items:
            href = f"{url}{item['href']}"
            value, currency = get_flat_clear_price(item.find('div', {'class':'_2LpFR'}))
            per_square_meter_price = get_flat_clear_per_square_meter_price(item.find('div', {'class':'_2OGaT'}).findChildren('div' , recursive=False)[0])
            rooms, square, floor, house_floor = get_info_flat(item.find('ul', {'class':'_1I9Cg'}).findAll('li' , {'class': '_2aoTm'}))
            metro_line, metro_station = get_info_metro(item.find('div', {'class':'sT_AF'}))            
            save_flat({'_id':href, 'value':value, 'currency':currency, 'psm_price':per_square_meter_price, 
                       'rooms':rooms, 'square':square, 'floor':floor, 'house_floor':house_floor, 
                       'metro_line':metro_line, 'metro_station':metro_station}, db_collection)
        if soup.find('a', {'rel': 'next'}) is not None:    
            next_page = f"{soup.find('a', {'rel': 'next'})['href']}"  
    return next_page

#обход страниц пока не дойдем до максимума или последней страницы
def parse_pages(url, params, debug):
    db_collection = init_db(debug)
    next_page = parse_one_page_sales(url, '/search', params, db_collection)
    i = 0
    while next_page is not None and i<MAX_PAGE:
        next_page = parse_one_page_sales(url, next_page, '', db_collection)
        i += 1
        time.sleep(5)

# %% [markdown]
# 1.4. Функции для работы с базой

# %%
#Функция сохранения в базу данных
def save_flat(item, db_collection):
    if db_collection.count_documents({ '_id': item['_id']}) == 0:
        db_collection.insert_one(item)
    
def init_db(debug):
    client = MongoClient('mongodb://127.0.0.1:27017')
    db = client['test']
    db_collection = db.flats
    if debug:
        db_collection.drop()
    return db_collection
                     
def get_flats():
    db_collection = init_db(False)
    cursor = db_collection.find({'currency':'₽'})     
    return list(cursor)

# %% [markdown]
# 1.5. Вызов функции парсинга

# %%
parse_pages(url, params, False)

# %% [markdown]
# 2.Построение модели предсказания цены

# %% [markdown]
# 2.1. Подключение библиотек предсказания

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score as r2
from sklearn.ensemble import RandomForestRegressor as RF

import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# 2.2. Функции подготовки данных

# %%
def create_dummies(df, columns):
    df = pd.get_dummies(df)
    missing_cols = set( columns ) - set( df.columns )
    for c in missing_cols:
        df[c] = 0
    return df

# Возвращает список некатегориальных столбцов
def get_noncategorical_columns(df):
    return [c for c in df.columns if df[c].dtype.name != 'object']

# %%
def get_feats(df):
    feats = get_noncategorical_columns(df)
    feats.remove('psm_price')
    feats.remove('value')
    return feats

def prepare_data(df):
    df = create_dummies(df, get_feats(df))    
    return df

# %% [markdown]
# 2.3. Загрузка данных из базы

# %%
flats = get_flats()
df = pd.DataFrame(flats)
df = df.drop({'_id'}, axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1980 entries, 0 to 1979
# Data columns (total 9 columns):
# currency         1980 non-null object
# floor            1980 non-null int64
# house_floor      1980 non-null int64
# metro_line       1980 non-null object
# metro_station    1980 non-null object
# psm_price        1980 non-null float64
# rooms            1980 non-null int64
# square           1980 non-null float64
# value            1980 non-null float64
# dtypes: float64(3), int64(3), object(3)
# memory usage: 139.3+ KB

# %%
df = prepare_data(df)
train, valid = train_test_split(df, test_size=0.3, random_state=62)
train.shape, valid.shape
# Out:
# ((1386, 197), (594, 197))

# %%
train.describe()
# Out:
#              floor  house_floor     psm_price        rooms       square  \
# count  1386.000000  1386.000000  1.386000e+03  1386.000000  1386.000000
# mean     12.714286    22.128427  3.530016e+05     2.739538   108.698947
# std      12.996608    17.251362  2.706766e+05     1.307842    64.702614
# min       1.000000     2.000000  1.320000e+02     0.000000    14.000000
# 25%       4.000000     9.000000  1.763508e+05     2.000000    60.150000
# 50%       8.000000    17.000000  2.644085e+05     3.000000    98.000000
# 75%      16.000000    26.000000  4.360522e+05     3.000000   140.150000
# max      80.000000    97.000000  2.296686e+06    16.000000   596.000000
#
#               value  currency_₽  metro_line_  metro_line_Арбатско-Покровская  \
# count  1.386000e+03      1386.0  1386.000000                     1386.000000
# mean   4.629932e+07         1.0     0.237374                        0.064214
# std    6.280625e+07         0.0     0.425627                        0.245221
# min    6.950000e+03         1.0     0.000000                        0.000000
# 25%    1.239925e+07         1.0     0.000000                        0.000000
# 50%    2.251747e+07         1.0     0.000000                        0.000000
# 75%    5.472500e+07         1.0     0.000000                        0.000000
# max    5.249568e+08         1.0     1.000000                        1.000000
#
#        metro_line_Бутовская          ...            metro_station_Чкаловская  \
# count           1386.000000          ...                         1386.000000
# mean               0.006494          ...                            0.005772
# std                0.080349          ...                            0.075781
# min                0.000000          ...                            0.000000
# 25%                0.000000          ...                            0.000000
# 50%                0.000000          ...                            0.000000
# 75%                0.000000          ...                            0.000000
# max                1.000000          ...                            1.000000
#
#        metro_station_Шаболовская  metro_station_Шелепиха  \
# count                1386.000000             1386.000000
# mean                    0.005772                0.005772
# std                     0.075781                0.075781
# min                     0.000000                0.000000
# 25%                     0.000000                0.000000
# 50%                     0.000000                0.000000
# 75%                     0.000000                0.000000
# max                     1.000000                1.000000
#
#        metro_station_Шипиловская  metro_station_Щелковская  \
# count                1386.000000               1386.000000
# mean                    0.000722                  0.003608
# std                     0.026861                  0.059976
# min                     0.000000                  0.000000
# 25%                     0.000000                  0.000000
# 50%                     0.000000                  0.000000
# 75%                     0.000000                  0.000000
# max                     1.000000                  1.000000
#
#        metro_station_Щукинская  metro_station_Электрозаводская  \
# count              1386.000000                     1386.000000
# mean                  0.007937                        0.000722
# std                   0.088765                        0.026861
# min                   0.000000                        0.000000
# 25%                   0.000000                        0.000000
# 50%                   0.000000                        0.000000
# 75%                   0.000000                        0.000000
# max                   1.000000                        1.000000
#
#        metro_station_Юго-Западная  metro_station_Южная  metro_station_Ясенево
# count                 1386.000000          1386.000000            1386.000000
# mean                     0.007937             0.002886               0.002165
# std                      0.088765             0.053663               0.046491
# min                      0.000000             0.000000               0.000000
# 25%                      0.000000             0.000000               0.000000
# 50%                      0.000000             0.000000               0.000000
# 75%                      0.000000             0.000000               0.000000
# max                      1.000000             1.000000               1.000000
#
# [8 rows x 197 columns]

# %%
valid.describe()
# Out:
#             floor  house_floor     psm_price       rooms      square  \
# count  594.000000   594.000000  5.940000e+02  594.000000  594.000000
# mean    12.570707    21.558923  3.385214e+05    2.658249  102.619175
# std     12.293456    16.545631  2.538167e+05    1.264127   61.195782
# min      1.000000     2.000000  2.110000e+02    0.000000   16.800000
# 25%      4.000000     9.000000  1.757815e+05    2.000000   59.200000
# 50%      8.000000    17.000000  2.398110e+05    3.000000   92.000000
# 75%     17.000000    25.000000  4.130232e+05    3.000000  134.275000
# max     77.000000    97.000000  1.749856e+06   10.000000  522.000000
#
#               value  currency_₽  metro_line_  metro_line_Арбатско-Покровская  \
# count  5.940000e+02       594.0   594.000000                      594.000000
# mean   4.181014e+07         1.0     0.225589                        0.058923
# std    5.835541e+07         0.0     0.418322                        0.235678
# min    5.290000e+03         1.0     0.000000                        0.000000
# 25%    1.232500e+07         1.0     0.000000                        0.000000
# 50%    1.985000e+07         1.0     0.000000                        0.000000
# 75%    4.575000e+07         1.0     0.000000                        0.000000
# max    5.500000e+08         1.0     1.000000                        1.000000
#
#        metro_line_Бутовская          ...            metro_station_Чкаловская  \
# count            594.000000          ...                          594.000000
# mean               0.003367          ...                            0.010101
# std                0.057977          ...                            0.100079
# min                0.000000          ...                            0.000000
# 25%                0.000000          ...                            0.000000
# 50%                0.000000          ...                            0.000000
# 75%                0.000000          ...                            0.000000
# max                1.000000          ...                            1.000000
#
#        metro_station_Шаболовская  metro_station_Шелепиха  \
# count                 594.000000              594.000000
# mean                    0.003367                0.010101
# std                     0.057977                0.100079
# min                     0.000000                0.000000
# 25%                     0.000000                0.000000
# 50%                     0.000000                0.000000
# 75%                     0.000000                0.000000
# max                     1.000000                1.000000
#
#        metro_station_Шипиловская  metro_station_Щелковская  \
# count                 594.000000                594.000000
# mean                    0.001684                  0.001684
# std                     0.041030                  0.041030
# min                     0.000000                  0.000000
# 25%                     0.000000                  0.000000
# 50%                     0.000000                  0.000000
# 75%                     0.000000                  0.000000
# max                     1.000000                  1.000000
#
#        metro_station_Щукинская  metro_station_Электрозаводская  \
# count               594.000000                      594.000000
# mean                  0.008418                        0.003367
# std                   0.091437                        0.057977
# min                   0.000000                        0.000000
# 25%                   0.000000                        0.000000
# 50%                   0.000000                        0.000000
# 75%                   0.000000                        0.000000
# max                   1.000000                        1.000000
#
#        metro_station_Юго-Западная  metro_station_Южная  metro_station_Ясенево
# count                  594.000000           594.000000                  594.0
# mean                     0.006734             0.001684                    0.0
# std                      0.081853             0.041030                    0.0
# min                      0.000000             0.000000                    0.0
# 25%                      0.000000             0.000000                    0.0
# 50%                      0.000000             0.000000                    0.0
# 75%                      0.000000             0.000000                    0.0
# max                      1.000000             1.000000                    0.0
#
# [8 rows x 197 columns]

# %% [markdown]
# 2.4. Построение модели

# %%
feats = get_feats(df)
model = RF(random_state=128, n_estimators=200, max_depth=12, max_features= 35, min_samples_leaf=2)
model.fit(train.loc[:, feats], train['value'])
pred_train = model.predict(train.loc[:, feats])
score_r2 = r2(train['value'], pred_train)
score_r2
# Out:
# 0.835614836662497

# %% [markdown]
# 2.5. Предсказание на дополнительной выборке для оценки корректности модели

# %%
pred_valid =  model.predict(valid.loc[:, feats])
score_r2 = r2(valid['value'], pred_valid)
score_r2
# Out:
# 0.7085451701120726

# %%
importances = model.feature_importances_
indices = np.argsort(importances)[::-1]
print("Feature importances:")
for f, idx in enumerate(indices):
    print("{:2d}. feature '{:5s}' ({:.4f})".format(f + 1, feats[idx], importances[idx]))
# Out:
# Feature importances:
#  1. feature 'square' (0.4593)
#  2. feature 'rooms' (0.1711)
#  3. feature 'house_floor' (0.0991)
#  4. feature 'floor' (0.0416)
#  5. feature 'metro_station_Парк культуры' (0.0243)
#  6. feature 'metro_station_Кропоткинская' (0.0198)
#  7. feature 'metro_line_Сокольническая' (0.0143)
#  8. feature 'metro_station_Тверская' (0.0135)
#  9. feature 'metro_line_Московское центральное кольцо' (0.0115)
# 10. feature 'metro_line_' (0.0114)
# 11. feature 'metro_line_Кольцевая' (0.0112)
# 12. feature 'metro_station_Чеховская' (0.0106)
# 13. feature 'metro_station_Фрунзенская' (0.0098)
# 14. feature 'metro_line_Калининская' (0.0095)
# 15. feature 'metro_station_' (0.0094)
# 16. feature 'metro_station_Спортивная' (0.0086)
# 17. feature 'metro_station_Ростокино' (0.0069)
# 18. feature 'metro_station_Ломоносовский проспект' (0.0056)
# 19. feature 'metro_line_Замоскворецкая' (0.0048)
# 20. feature 'metro_station_Смоленская' (0.0040)
# 21. feature 'metro_station_Деловой центр' (0.0039)
# 22. feature 'metro_station_Маяковская' (0.0038)
# 23. feature 'metro_station_Баррикадная' (0.0036)
# 24. feature 'metro_line_Таганско-Краснопресненская' (0.0032)
# 25. feature 'metro_station_Новокузнецкая' (0.0032)
# 26. feature 'metro_line_Серпуховско-Тимирязевская' (0.0032)
# 27. feature 'metro_station_Минская' (0.0030)
# 28. feature 'metro_station_Арбатская' (0.0027)
# 29. feature 'metro_station_Трубная' (0.0026)
# 30. feature 'metro_station_Киевская' (0.0022)
# 31. feature 'metro_line_Арбатско-Покровская' (0.0021)
# 32. feature 'metro_station_Полянка' (0.0021)
# 33. feature 'metro_line_Филевская' (0.0017)
# 34. feature 'metro_line_Калужско-Рижская' (0.0015)
# 35. feature 'metro_station_Новослободская' (0.0015)
# 36. feature 'metro_station_Улица 1905 года' (0.0015)
# 37. feature 'metro_line_Люблинско-Дмитровская' (0.0013)
# 38. feature 'metro_station_Чкаловская' (0.0011)
# 39. feature 'metro_station_Третьяковская' (0.0009)
# 40. feature 'metro_station_Проспект Вернадского' (0.0008)
# 41. feature 'metro_station_Студенческая' (0.0007)
# 42. feature 'metro_station_Кунцевская' (0.0006)
# 43. feature 'metro_station_Международная' (0.0006)
# 44. feature 'metro_station_Красные ворота' (0.0006)
# 45. feature 'metro_station_Щукинская' (0.0005)
# 46. feature 'metro_station_Курская' (0.0005)
# 47. feature 'metro_station_Раменки' (0.0004)
# 48. feature 'metro_station_Юго-Западная' (0.0003)
# 49. feature 'metro_station_Тропарево' (0.0003)
# 50. feature 'metro_station_Белорусская' (0.0003)
# 51. feature 'metro_station_Театральная' (0.0003)
# 52. feature 'metro_station_Достоевская' (0.0002)
# 53. feature 'metro_station_Измайловская' (0.0002)
# 54. feature 'metro_station_Славянский бульвар' (0.0002)
# 55. feature 'metro_station_Аэропорт' (0.0002)
# 56. feature 'metro_station_Таганская' (0.0002)
# 57. feature 'metro_station_Сокол' (0.0001)
# 58. feature 'metro_station_Бауманская' (0.0001)
# 59. feature 'metro_station_Менделеевская' (0.0001)
# 60. feature 'metro_station_Коптево' (0.0001)
# 61. feature 'metro_station_Профсоюзная' (0.0001)
# 62. feature 'metro_station_Сходненская' (0.0001)
# 63. feature 'metro_station_Свиблово' (0.0001)
# 64. feature 'metro_station_Парк Победы' (0.0001)
# 65. feature 'metro_station_ВДНХ' (0.0001)
# 66. feature 'metro_station_Лужники' (0.0001)
# 67. feature 'metro_station_Преображенская площадь' (0.0001)
# 68. feature 'metro_station_Братиславская' (0.0001)
# 69. feature 'metro_station_Молодежная' (0.0001)
# 70. feature 'metro_station_Тимирязевская' (0.0000)
# 71. feature 'metro_station_Хорошево' (0.0000)
# 72. feature 'metro_station_Ботанический сад' (0.0000)
# 73. feature 'metro_station_Университет' (0.0000)
# 74. feature 'metro_station_Чистые пруды' (0.0000)
# 75. feature 'metro_station_Марьина Роща' (0.0000)
# 76. feature 'metro_station_Шелепиха' (0.0000)
# 77. feature 'metro_line_Бутовская' (0.0000)
# 78. feature 'metro_station_Шаболовская' (0.0000)
# 79. feature 'metro_station_Новые Черемушки' (0.0000)
# 80. feature 'metro_station_Щелковская' (0.0000)
# 81. feature 'metro_station_Водный стадион' (0.0000)
# 82. feature 'metro_station_Павелецкая' (0.0000)
# 83. feature 'metro_station_Крылатское' (0.0000)
# 84. feature 'metro_station_Китай-город' (0.0000)
# 85. feature 'metro_station_Октябрьское поле' (0.0000)
# 86. feature 'metro_station_Проспект Мира' (0.0000)
# 87. feature 'metro_station_Рязанский проспект' (0.0000)
# 88. feature 'metro_station_Красносельская' (0.0000)
# 89. feature 'metro_station_Южная' (0.0000)
# 90. feature 'metro_station_Тульская' (0.0000)
# 91. feature 'metro_station_Владыкино' (0.0000)
# 92. feature 'metro_station_Марьино' (0.0000)
# 93. feature 'metro_station_Беговая' (0.0000)
# 94. feature 'metro_station_Алтуфьево' (0.0000)
# 95. feature 'metro_station_Пятницкое шоссе' (0.0000)
# 96. feature 'metro_station_Бабушкинская' (0.0000)
# 97. feature 'metro_station_Багратионовская' (0.0000)
# 98. feature 'metro_station_Динамо' (0.0000)
# 99. feature 'metro_station_Сокольники' (0.0000)
# 100. feature 'metro_station_Серпуховская' (0.0000)
# 101. feature 'metro_station_Выставочная' (0.0000)
# 102. feature 'metro_station_Беляево' (0.0000)
# 103. feature 'metro_station_Митино' (0.0000)
# 104. feature 'metro_station_Люблино' (0.0000)
# 105. feature 'metro_station_Текстильщики' (0.0000)
# 106. feature 'metro_station_Домодедовская' (0.0000)
# 107. feature 'metro_station_Нагатинская' (0.0000)
# 108. feature 'metro_station_Ховрино' (0.0000)
# 109. feature 'metro_station_Алексеевская' (0.0000)
# 110. feature 'metro_station_Выхино' (0.0000)
# 111. feature 'metro_line_Каховская' (0.0000)
# 112. feature 'metro_station_Речной вокзал' (0.0000)
# 113. feature 'metro_station_Бибирево' (0.0000)
# 114. feature 'metro_station_Ясенево' (0.0000)
# 115. feature 'metro_station_Стрешнево' (0.0000)
# 116. feature 'metro_station_Аннино' (0.0000)
# 117. feature 'metro_station_Крымская' (0.0000)
# 118. feature 'metro_station_Панфиловская' (0.0000)
# 119. feature 'metro_station_Пражская' (0.0000)
# 120. feature 'metro_station_Улица Скобелевская' (0.0000)
# 121. feature 'metro_station_Бунинская аллея' (0.0000)
# 122. feature 'metro_station_Калужская' (0.0000)
# 123. feature 'metro_station_Улица Академика Янгеля' (0.0000)
# 124. feature 'metro_station_Марксистская' (0.0000)
# 125. feature 'metro_station_Кантемировская' (0.0000)
# 126. feature 'metro_station_Фили' (0.0000)
# 127. feature 'metro_station_Автозаводская' (0.0000)
# 128. feature 'metro_station_Новоясеневская' (0.0000)
# 129. feature 'metro_station_Орехово' (0.0000)
# 130. feature 'metro_station_Каховская' (0.0000)
# 131. feature 'metro_station_Фонвизинская' (0.0000)
# 132. feature 'metro_station_Коломенская' (0.0000)
# 133. feature 'metro_station_Медведково' (0.0000)
# 134. feature 'metro_station_Электрозаводская' (0.0000)
# 135. feature 'metro_station_Бутырская ' (0.0000)
# 136. feature 'currency_₽' (0.0000)
# 137. feature 'metro_station_Андроновка' (0.0000)
# 138. feature 'metro_station_Алма-Атинская' (0.0000)
# 139. feature 'metro_station_Бульвар Рокоссовского' (0.0000)
# 140. feature 'metro_station_Чертановская' (0.0000)
# 141. feature 'metro_station_Бульвар Дмитрия Донского' (0.0000)
# 142. feature 'metro_station_Шипиловская' (0.0000)
# 143. feature 'metro_station_Академическая' (0.0000)
# 144. feature 'metro_station_Варшавская' (0.0000)
# 145. feature 'metro_station_Борисово' (0.0000)
# 146. feature 'metro_station_Битцевский Парк' (0.0000)
# 147. feature 'metro_station_Балтийская' (0.0000)
# 148. feature 'metro_station_Улица Горчакова' (0.0000)
# 149. feature 'metro_station_Волжская' (0.0000)
# 150. feature 'metro_station_Полежаевская' (0.0000)
# 151. feature 'metro_station_Новокосино' (0.0000)
# 152. feature 'metro_station_Новохохловская' (0.0000)
# 153. feature 'metro_station_Отрадное' (0.0000)
# 154. feature 'metro_station_Охотный ряд' (0.0000)
# 155. feature 'metro_station_Первомайская' (0.0000)
# 156. feature 'metro_station_Петровско-Разумовская' (0.0000)
# 157. feature 'metro_station_Печатники' (0.0000)
# 158. feature 'metro_station_Пионерская' (0.0000)
# 159. feature 'metro_station_Планерная' (0.0000)
# 160. feature 'metro_station_Пролетарская' (0.0000)
# 161. feature 'metro_station_Нижегородская' (0.0000)
# 162. feature 'metro_station_Римская' (0.0000)
# 163. feature 'metro_station_Савеловская' (0.0000)
# 164. feature 'metro_station_Севастопольская' (0.0000)
# 165. feature 'metro_station_Соколиная Гора' (0.0000)
# 166. feature 'metro_station_Сретенский бульвар' (0.0000)
# 167. feature 'metro_station_Строгино' (0.0000)
# 168. feature 'metro_station_Сухаревская' (0.0000)
# 169. feature 'metro_station_Технопарк' (0.0000)
# 170. feature 'metro_station_Тургеневская' (0.0000)
# 171. feature 'metro_station_Новогиреево' (0.0000)
# 172. feature 'metro_station_Нахимовский проспект' (0.0000)
# 173. feature 'metro_station_Волоколамская' (0.0000)
# 174. feature 'metro_station_Комсомольская' (0.0000)
# 175. feature 'metro_station_Цветной бульвар' (0.0000)
# 176. feature 'metro_station_Дмитровская' (0.0000)
# 177. feature 'metro_station_Добрынинская' (0.0000)
# 178. feature 'metro_station_Дубровка' (0.0000)
# 179. feature 'metro_station_ЗИЛ' (0.0000)
# 180. feature 'metro_station_Зорге' (0.0000)
# 181. feature 'metro_station_Зябликово' (0.0000)
# 182. feature 'metro_station_Каширская' (0.0000)
# 183. feature 'metro_station_Кожуховская' (0.0000)
# 184. feature 'metro_station_Коньково' (0.0000)
# 185. feature 'metro_station_Нагорная' (0.0000)
# 186. feature 'metro_station_Краснопресненская' (0.0000)
# 187. feature 'metro_station_Крестьянская застава' (0.0000)
# 188. feature 'metro_station_Царицыно' (0.0000)
# 189. feature 'metro_station_Кузьминки' (0.0000)
# 190. feature 'metro_station_Ленинский проспект' (0.0000)
# 191. feature 'metro_station_Лермонтовский проспект' (0.0000)
# 192. feature 'metro_station_Локомотив' (0.0000)
# 193. feature 'metro_station_Лубянка' (0.0000)
# 194. feature 'metro_station_Мякинино' (0.0000)
# 195. feature 'metro_station_Кутузовская' (0.0000)
